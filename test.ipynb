# %%
# Install Ultralytics (for YOLOv8)
# !pip install ultralytics roboflow

# Import necessary libraries
from roboflow import Roboflow

rf = Roboflow(api_key="vKYQy8T8tyxUkT70rnq3")
project = rf.workspace("model-njgqi").project("pens-cyqs3")
version = project.version(2)
dataset = version.download("yolov8")

# Check if YOLOv8 is installed properly
from ultralytics import YOLO

# Train YOLOv8 Model
# !yolo task=detect mode=train model=yolov8s.pt data=/content/pens-2/data.yaml epochs=100 imgsz=640 batch=16 device=0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.8/974.8 kB 45.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 86.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 76.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 63.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.3 MB/s eta 0:00:00
# ...

# %%
# Install Ultralytics (for YOLOv8)
# !pip install ultralytics
import os
import zipfile
import gdown
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Google Drive file IDs
IMAGE_ZIP_ID = "1POLYx5iMP2SIdboPZrkfApHmC7LZW19C"
MODEL_FILE_ID = "1BLIy4NB0j3WMdKXoelCypeZCyFopWrAF"

# Define file paths
IMAGE_ZIP_PATH = "/content/images.zip"
MODEL_PATH = "/content/yolov8_model.pt"
IMAGE_DIR = "/content/images/test/test"

# Download images zip
#gdown.download(f"https://drive.google.com/uc?id={IMAGE_ZIP_ID}", IMAGE_ZIP_PATH, quiet=False)

# Download YOLOv8 model
#gdown.download(f"https://drive.google.com/uc?id={MODEL_FILE_ID}", MODEL_PATH, quiet=False)

# Extract images
#os.makedirs(IMAGE_DIR, exist_ok=True)
#with zipfile.ZipFile(IMAGE_ZIP_PATH, 'r') as zip_ref:
#    zip_ref.extractall(IMAGE_DIR)

# Load YOLOv8 model
model = YOLO(MODEL_PATH)

# Run inference on all images in the directory
image_files = [os.path.join(IMAGE_DIR, f) for f in os.listdir(IMAGE_DIR) if f.endswith(('.png', '.jpg', '.jpeg'))]

for image_file in image_files:
    results = model(image_file)

    # Display results
    for result in results:
        img = cv2.imread(image_file)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        plt.figure(figsize=(8, 6))
        plt.imshow(result.plot())  # YOLO automatically plots detections
        plt.axis("off")
        plt.title(f"Detections for {os.path.basename(image_file)}")
        plt.show()
# Out:
# ...
#
# image 1/1 /content/images/test/test/pic4.jpg: 512x640 2 pens, 37.0ms
# Speed: 19.8ms preprocess, 37.0ms inference, 393.2ms postprocess per image at shape (1, 3, 512, 640)
# image 1/1 /content/images/test/test/pic3.jpg: 512x640 1 pen, 13.1ms
# Speed: 3.1ms preprocess, 13.1ms inference, 2.4ms postprocess per image at shape (1, 3, 512, 640)
# image 1/1 /content/images/test/test/pic2.jpg: 512x640 2 pens, 13.1ms
# Speed: 4.0ms preprocess, 13.1ms inference, 2.4ms postprocess per image at shape (1, 3, 512, 640)
# image 1/1 /content/images/test/test/pic1.jpg: 512x640 1 pen, 13.2ms
# Speed: 4.0ms preprocess, 13.2ms inference, 2.9ms postprocess per image at shape (1, 3, 512, 640)
